# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as n
import pandas as p
import seaborn as sb
from matplotlib import pyplot as plt

# %%
#Read Excel File
Emp_Dataset = p.read_excel(r"C:\Users\1\Desktop\PB\myexcel.xlsx")
Emp_Dataset
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
# Data Pre Processing Replacing Null values using Random Numbers
Emp_Dataset["Height"]= n.random.randint(150 , 185 ,458)
Emp_Dataset["Weight"]= n.random.randint(60 , 100 ,458)

Emp_Dataset
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175      90
# 1      Jae Crowder  Boston Celtics      99       SF   25     178      65
# 2     John Holland  Boston Celtics      30       SG   27     160      73
# 3      R.J. Hunter  Boston Celtics      28       SG   22     154      80
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     182      62
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     163      60
# 454      Raul Neto       Utah Jazz      25       PG   24     162      83
# 455   Tibor Pleiss       Utah Jazz      21        C   26     174      78
# 456    Jeff Withey       Utah Jazz      24        C   26     174      96
# 457       Priyanka       Utah Jazz      34        C   25     165      71
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 1. Calculate total count by team 
Team_Count =  Emp_Dataset["Team"].value_counts()

# How many are there in each Team and the percentage splitting with respect to the total employees.
Team_Name=p.Series(Emp_Dataset["Team"].unique())
print(Team_Count)
# Using Pie Chart
print("\n\n-----PIE CHART------\n\n")
plt.pie(Team_Count ,labels=Team_Name,autopct="%1.1f%%")
plt.figure(figsize= (50, 50))
plt.show()

# BAr chart for plotting Team 
print("\n\n-----BAR CHART-----\n\n")
plt.bar(Team_Name,Team_Count, color = "Green")


plt.figure(figsize= (50,100))
plt.show()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
#
#
# -----PIE CHART------
# ...

# %%
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     177      61
# 1      Jae Crowder  Boston Celtics      99       SF   25     167      76
# 2     John Holland  Boston Celtics      30       SG   27     163      95
# 3      R.J. Hunter  Boston Celtics      28       SG   22     184      77
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     181      62
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166      66
# 454      Raul Neto       Utah Jazz      25       PG   24     174      98
# 455   Tibor Pleiss       Utah Jazz      21        C   26     166      76
# 456    Jeff Withey       Utah Jazz      24        C   26     155      86
# 457       Priyanka       Utah Jazz      34        C   25     161      93
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
Emp_Dataset.to_csv(r"C:\Users\1\Desktop\PB\myexcel_Final.csv")

# %%
# Out:
#      Unnamed: 0           Name            Team  Number Position  Age  Height  \
# 0             0  Avery Bradley  Boston Celtics       0       PG   25     161
# 1             1    Jae Crowder  Boston Celtics      99       SF   25     180
# 2             2   John Holland  Boston Celtics      30       SG   27     152
# 3             3    R.J. Hunter  Boston Celtics      28       SG   22     169
# 4             4  Jonas Jerebko  Boston Celtics       8       PF   29     164
# ..          ...            ...             ...     ...      ...  ...     ...
# 453         453   Shelvin Mack       Utah Jazz       8       PG   26     182
# 454         454      Raul Neto       Utah Jazz      25       PG   24     179
# 455         455   Tibor Pleiss       Utah Jazz      21        C   26     181
# 456         456    Jeff Withey       Utah Jazz      24        C   26     156
# 457         457       Priyanka       Utah Jazz      34        C   25     163
#
#      Weight            College     Salary
# ...

# %%
# Total count of employees in different position

Pos_Cnt =  Emp_Dataset["Position"].value_counts()
Pos_Cnt
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#2.  Segregate the employees w.r.t different positions.
print("****Employees in SG Position*****\n",Emp_Dataset.loc[(Emp_Dataset["Position"]=="SG")])
print("\n****Employees in PF Position****\n",Emp_Dataset.loc[(Emp_Dataset["Position"]=="PF")])
print("\n-----Employees in PG Position-----\n",Emp_Dataset.loc[(Emp_Dataset["Position"]=="PG")])
print("\n++++++Employees in SF Position+++++\n",Emp_Dataset.loc[(Emp_Dataset["Position"]=="SF")])
print("\n*****Employees in C Position******\n",Emp_Dataset.loc[(Emp_Dataset["Position"]=="C")])
# Out:
# ****Employees in SG Position*****
#                   Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     160
# 3         R.J. Hunter          Boston Celtics      28       SG   22     154
# 12        Evan Turner          Boston Celtics      11       SG   27     180
# 13        James Young          Boston Celtics      13       SG   20     157
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     163
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     157
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     156
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     181
# 444        Alec Burks               Utah Jazz      10       SG   24     164
# 449       Rodney Hood               Utah Jazz       5       SG   23     159
#
# ...

# %%
# 3..Find from which age group most of the employees belong to.
print(Emp_Dataset["Age"].value_counts())
DF=Emp_Dataset[(Emp_Dataset["Age"]>=24) & (Emp_Dataset["Age"]<=36)]
print("\n\n----Details of employees---- \n\n",DF)
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64
#
#
# ----Details of employees----
#
#                Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     177      61
# 1      Jae Crowder  Boston Celtics      99       SF   25     167      76
# 2     John Holland  Boston Celtics      30       SG   27     163      95
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     181      62
# 5     Amir Johnson  Boston Celtics      90       PF   29     156      77
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166      66
# 454      Raul Neto       Utah Jazz      25       PG   24     174      98
# ...

# %%
# Histogram for plotting the Age group where most of the employees belong

age=Emp_Dataset["Age"]
age
plt.hist(age,bins=[15,20,25,30,35,40,45,50,55])
plt.legend("Age")
plt.show()

# %%
#4. Find out under which team and position, spending in terms of salary is high
s=Emp_Dataset["Salary"].max()
Emp_Dataset[(Emp_Dataset["Salary"]==s)]
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     172      82
#
#     College      Salary
# 109     NaN  25000000.0

# %%
# Position and count scatter plot
pos=Emp_Dataset["Position"].unique()
plt.scatter(pos, Pos_Cnt, color="violet")
plt.figure(figsize= (50, 50))
plt.show()

# %%
#5.Find if there is any correlation between age and salary , represent it visually.

New=Emp_Dataset[["Age","Salary"]]
print("Correlation between Age and Salary---\n\n")
print(New.corr())

#Correlation Matrix 

# Correlation Matrix of Age and Salary

print("\n-----Correlation Matrix------ \n\n")
cbar = False
linewidths=1.5
linecolor = "white"
sb.heatmap(New.corr(),linewidth=linewidths , linecolor=linecolor,cbar=cbar, annot=True,cmap="PiYG" )
# Out:
# Correlation between Age and Salary---
#
#
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000
#
# -----Correlation Matrix------
# <Axes: >

# %%
Emp_Dataset
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     162      88
# 1      Jae Crowder  Boston Celtics      99       SF   25     161      86
# 2     John Holland  Boston Celtics      30       SG   27     183      60
# 3      R.J. Hunter  Boston Celtics      28       SG   22     179      96
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     164      94
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     171      93
# 454      Raul Neto       Utah Jazz      25       PG   24     151      77
# 455   Tibor Pleiss       Utah Jazz      21        C   26     165      68
# 456    Jeff Withey       Utah Jazz      24        C   26     167      82
# 457       Priyanka       Utah Jazz      34        C   25     177      61
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
Emp_Dataset.to_excel("D:\Python_project_EmpDataset_Final.xlsx")

# %%
# Out:
# <Axes: >

# %%
Emp_Dataset.to_excel("D:\Python_project_EmpDataset.xlsx")
